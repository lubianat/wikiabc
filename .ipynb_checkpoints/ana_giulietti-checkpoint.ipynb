# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import date, datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys


driver = webdriver.Firefox()
ordem_url = "https://canalciencia.ibict.br/noticias/item/237-ordem-nacional-do-merito-cientifico"
driver.get(ordem_url)
great_cross_selector = "#k2Container > div.itemBody > div.itemFullText > p:nth-child(7)"
comendador_selector = "#k2Container > div.itemBody > div.itemFullText > p:nth-child(11)"
elem_cross = driver.find_element_by_css_selector(great_cross_selector)
elem_comendador = driver.find_element_by_css_selector(comendador_selector)

great_cross_string = elem_cross.text
comendador_string = elem_comendador.text

# %%
women_abc_df = pd.read_csv("women_at_ABC_26_11_2020.csv")

great_cross_women = women_abc_df[[name in great_cross_string for name in women_abc_df["name"]]]
comendador_women =  women_abc_df[[name in comendador_string for name in women_abc_df["name"]]]

# %%
import wikipedia

def prepare_df_to_create(base_df):
    wikipedia.set_lang("pt")

    wiki_dict = {}
    for i, row in base_df.iterrows():
        print(i)

        try:
            page = wikipedia.page(row["name"])
            wiki = page.url
        except:
            wiki = ""

        wiki_dict[row["name"]] = wiki
    
    base_df["wikipedia"] = base_df["name"].map(wiki_dict)
    base_df = [(a == "" or "Lista" in a) for a in base_df["wikipedia"] ]

    return base_df

# %%
to_create_comendador = prepare_df_to_create(comendador_women)
# Out:
# 0
# 1
# 8
# 10
# 11
# 12
# 19
# 22
# 23
# 29
# 32
# 36
# 38
# 39
# 41
# 47
# 48
# 49
# 51
# 52
# 53
# 54
# 67
# 68
# 72
# 81
# 82
# 86
# 87
# 88
# 90
# 92
# /home/lubianat/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
to_create_comendador[to_create]
# Out:
#     Unnamed: 0                                name  \
# 22          22  Concepta Margaret McManus Pimentel
# 29          29    Elizabeth Pacheco Batista Fontes
# 51          51                  Maria Inês Schmidt
# 52          52                 Maria José Pacifico
# 53          53             Maria Júlia Manso Alves
# 81          81          Sara Teresinha Olalla Saad
# 87          87             Valderez Pinto Ferreira
# 92          92                 Yoshiko Wakabayashi
#
#                                                   url  \
# 22  http://www.abc.org.br/membro/concepta-margaret...
# 29  http://www.abc.org.br/membro/elizabeth-pacheco...
# 51   http://www.abc.org.br/membro/maria-ines-schmidt/
# 52  http://www.abc.org.br/membro/maria-jose-pacifico/
# 53  http://www.abc.org.br/membro/maria-julia-manso...
# 81  http://www.abc.org.br/membro/sara-teresinha-ol...
# 87  http://www.abc.org.br/membro/valderez-pinto-fe...
# 92  http://www.abc.org.br/membro/yoshiko-wakabayashi/
#
#                                             wikipedia
# 22
# 29  https://pt.wikipedia.org/wiki/Lista_de_membros...
# 51  https://pt.wikipedia.org/wiki/Lista_de_membros...
# 52
# 53  https://pt.wikipedia.org/wiki/Lista_de_membros...
# 81  https://pt.wikipedia.org/wiki/Lista_de_membros...
# 87
# 92  https://pt.wikipedia.org/wiki/Lista_de_agracia...

# %%
to_create
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a7e1b651d446> in <module>
# ----> 1 to_create
#
# NameError: name 'to_create' is not defined

# %%
to_create_great_cross.to_csv("to_create_great_cross_women_14_01_2021.csv", index=False)
to_create_comendador.to_csv("to_create_comendador_women_14_01_2021.csv", index=False)
# Out:
# 0
# 10
# 12
# 23
# 25
# 28
# 32
# 37
# 49
# 65
# 79
# 94
#     Unnamed: 0                                   name  \
# 0            0               Alaíde Braga de Oliveira
# 10          10               Antoniana Ursine Krettli
# 12          12                         Belita Koiller
# 23          23                          Débora Foguel
# 25          25                 Dora Selma Fix Ventura
# 28          28  Elisa Maria da Conceição Pereira Reis
# 32          32                  Helena Bonciani Nader
# 37          37                 Laura de Mello e Souza
# 49          49                 Maria Domingues Vargas
# 65          65                            Mayana Zatz
